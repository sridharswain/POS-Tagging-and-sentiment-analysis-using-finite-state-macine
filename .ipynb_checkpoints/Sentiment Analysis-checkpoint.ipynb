# %%
from textblob import TextBlob
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from credentials import *
import tweepy
import re
from pprint import pprint

# %%
dummy = 'he is more fake'
blob = TextBlob(dummy)
print(blob.tags)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# [('he', 'PRP'), ('is', 'VBZ'), ('more', 'RBR'), ('fake', 'JJ')]
# 0.0

# %%
def drawGraph(matrix,labels):
    labels = {value : key for key,value in labels.items()}
    value = np.array(matrix)
    G = nx.DiGraph(value)
    pos=nx.draw_networkx_labels(G,nx.shell_layout(G),labels,font_size=16)
    nx.draw(G,nx.shell_layout(G),node_size=1500)
    plt.show()

# %%
#print(ACCESS_SECRET)
def twitterSetup():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN,  'cPOc0ksOYevSh5wfeStWa3OHXXjMSoEFoIvXgUI27Q1F7')
    api = tweepy.API(auth)
    return api

tweetsFile = open('tweets.txt','a')
extractor = twitterSetup()
tweets = []
for p in range(1,5):
    partTweets = extractor.user_timeline(screen_name="realDonaldTrump", count=500,page=p)
    for line in partTweets:
        tweets.append(line.text)
    print("Number of tweets extracted: {}.\n".format(len(tweets)))
# Out:
# Number of tweets extracted: 200.
#
# Number of tweets extracted: 400.
#
# Number of tweets extracted: 600.
#
# Number of tweets extracted: 797.

# %%
allTweets = [re.sub('\W+',' ', tweet) for tweet in [' '.join(rawTweet.split(' ')[:-1]) for rawTweet in tweets]]
print("5 recent tweets:\n")
for tweet in allTweets[0:5]:
    print(tweet)
# Out:
# 5 recent tweets:
#
# Our Nation was founded by farmers Our independence was won by farmers And our continent was tamed by farmers Our
# The Democrats do not want to help DACA Would be so easy to make a
# RT WhiteHouse The opioid crisis has created stories of despair of shock but also stories of recovery amp hope President Trump is asking
# A total WITCH HUNT with massive conflicts of
#  seanhannity on foxandfriends now Great 8 18

# %%
sentences = ["I ate a delicious hamburger.",
            "Zack joins the Sprockets Academy Explorers Club at school",
            "Zack gets paired up with Seth, the class bully, and that's dreadful but Zack is excited when he finds a huge galaxy gemmite",
            "A gemmite that large was found in last 100 years",
            "My favorite part is that the bird tried and learned that she could fly",
            "The bird has to decide if it will try to fly",
            "it was not sure if it wants to be happy",
            "One fateful day they make the acquaintance of the Cotton family"]
matrix = [[0 for i in range(37)] for j in range(37)]
indexMap = {'CC':0,'CD':1,'DT':2,'EX':3,'FW':4,'IN':5,'JJ':6,'JJR':7,'JJS':8,'LS':9,'MD':10,'NN':11,'NNP':13,'NNPS':14,'NNS':12,'PDT':15,
            'POS':16,'PRP':17,'PRP$':18,'RB':19,'RBR':20,'RBS':21,'RP':22,'SYM':23,'TO':24,'UH':25,'VB':26,'VBD':27,'VBG':28,'VBN':29,'VBP':30,'VBZ':31,'WDT':32,'WP':33,'WP$':34,'WRB':35,'end':36}
posToNeg = {}
negToPos = {}
toConsider = ['JJ','JJR','JJS', 'RB','RBR','RBS','VB','VBD','VBG','VBN','VBP','VBZ']
allTweets.extend(sentences)
combWords = []
for text in allTweets:
    blob = TextBlob(text)
    tags = blob.tags
    for i in range(1,len(tags)):
        x = indexMap[tags[i-1][1]]
        y = indexMap[tags[i][1]]
        matrix[x][y] +=1
    matrix[indexMap[tags[-1][1]]][-1] = 1
    polarity = 0
    if blob.sentences[0].sentiment.polarity>0.0:
        polarity = 1
    elif blob.sentences[0].sentiment.polarity<0.0:
        polarity =-1
    cWords = []
    for i in range(len(tags)):
        if(tags[i][1] not in toConsider):
            continue
        split = text.split(" ")
        join = split[:i]
        join.extend(split[i+1:])
        sc = ' '.join(join)
        b = TextBlob(sc)
        if(len(b.sentences)<1):
            continue 
        rawPol = b.sentences[0].sentiment.polarity
        tempPolarity = 0
        if rawPol>0.0:
            tempPolarity = 1
        elif rawPol<0.0:
            tempPolarity =-1
        if(polarity>tempPolarity):
            x = (tags[i][0].lower(),tags[i][1])
            negToPos[x] = 1
            cWords.append(x)
        elif(polarity<tempPolarity):
            x = (tags[i][0].lower(),tags[i][1])
            posToNeg[x] = 1
            cWords.append(x)
    combWords.append(cWords)

# %%
pprint(posToNeg)
print()
pprint(negToPos)
# Out:
# {("'s", 'VBZ'): 1,
#  ('approximately', 'RB'): 1,
#  ('bad', 'JJ'): 1,
#  ('big', 'JJ'): 1,
#  ('boring', 'JJ'): 1,
#  ('come', 'VB'): 1,
#  ('corrupt', 'JJ'): 1,
#  ('cutting', 'VBG'): 1,
#  ('desperate', 'JJ'): 1,
#  ('desperately', 'RB'): 1,
#  ('destroy', 'VB'): 1,
#  ('difficult', 'JJ'): 1,
#  ('disappointed', 'VBD'): 1,
#  ('dishonest', 'JJS'): 1,
#  ('down', 'RB'): 1,
#  ('everyday', 'JJ'): 1,
#  ('expected', 'VBN'): 1,
#  ('failed', 'JJ'): 1,
#  ('fake', 'JJ'): 1,
#  ('foreign', 'JJ'): 1,
#  ('guilty', 'JJ'): 1,
#  ('half', 'JJ'): 1,
#  ('hard', 'JJ'): 1,
#  ('hard', 'RB'): 1,
#  ('hated', 'JJ'): 1,
#  ('heavy', 'JJ'): 1,
#  ('horrible', 'JJ'): 1,
#  ('illegal', 'JJ'): 1,
#  ('insecure', 'JJ'): 1,
#  ('little', 'JJ'): 1,
#  ('long', 'JJ'): 1,
#  ('long', 'RB'): 1,
#  ('not', 'RB'): 1,
#  ('other', 'JJ'): 1,
#  ('outdated', 'VBN'): 1,
#  ('political', 'JJ'): 1,
#  ('previous', 'JJ'): 1,
#  ('repellent', 'JJ'): 1,
#  ('roughly', 'RB'): 1,
#  ('sad', 'JJ'): 1,
#  ('sadly', 'RB'): 1,
#  ('secret', 'JJ'): 1,
#  ('simple', 'JJ'): 1,
#  ('sloppy', 'JJ'): 1,
#  ('small', 'JJ'): 1,
#  ('stupid', 'JJ'): 1,
#  ('stupidly', 'RB'): 1,
#  ('terrible', 'JJ'): 1,
#  ('tough', 'JJ'): 1,
#  ('tragic', 'JJ'): 1,
#  ('unable', 'JJ'): 1,
#  ('unfair', 'JJ'): 1,
#  ('unnecessary', 'JJ'): 1,
#  ('very', 'RB'): 1,
#  ('weak', 'JJ'): 1,
#  ('weakly', 'JJ'): 1,
#  ('worse', 'JJR'): 1,
#  ('worst', 'JJS'): 1}
#
# {('able', 'JJ'): 1,
#  ('amazing', 'JJ'): 1,
#  ('appreciated', 'VBN'): 1,
#  ('be', 'VB'): 1,
#  ('beautiful', 'JJ'): 1,
#  ('beloved', 'JJ'): 1,
#  ('best', 'JJS'): 1,
#  ('better', 'JJR'): 1,
#  ('brave', 'JJ'): 1,
#  ('brave', 'VBP'): 1,
#  ('complete', 'JJ'): 1,
#  ('delicious', 'JJ'): 1,
#  ('dishonest', 'JJS'): 1,
#  ('easy', 'JJ'): 1,
#  ('economic', 'JJ'): 1,
#  ('extraordinary', 'JJ'): 1,
#  ('fantastic', 'JJ'): 1,
#  ('far', 'RB'): 1,
#  ('fast', 'RB'): 1,
#  ('filled', 'VBN'): 1,
#  ('first', 'JJ'): 1,
#  ('first', 'RB'): 1,
#  ('fly', 'VB'): 1,
#  ('free', 'JJ'): 1,
#  ('full', 'JJ'): 1,
#  ('good', 'JJ'): 1,
#  ('great', 'JJ'): 1,
#  ('greatest', 'JJS'): 1,
#  ('happy', 'JJ'): 1,
#  ('higher', 'JJR'): 1,
#  ('highly', 'RB'): 1,
#  ('important', 'JJ'): 1,
#  ('including', 'VBG'): 1,
#  ('incredible', 'JJ'): 1,
#  ('innocent', 'JJ'): 1,
#  ('intense', 'JJ'): 1,
#  ('interested', 'JJ'): 1,
#  ('interested', 'VBN'): 1,
#  ('large', 'JJ'): 1,
#  ('legal', 'JJ'): 1,
#  ('live', 'JJ'): 1,
#  ('live', 'VB'): 1,
#  ('looking', 'VBG'): 1,
#  ('love', 'VBP'): 1,
#  ('loved', 'VBN'): 1,
#  ('major', 'JJ'): 1,
#  ('many', 'JJ'): 1,
#  ('meaningful', 'JJ'): 1,
#  ('more', 'JJR'): 1,
#  ('more', 'RBR'): 1,
#  ('most', 'JJS'): 1,
#  ('most', 'RBS'): 1,
#  ('much', 'JJ'): 1,
#  ('much', 'RB'): 1,
#  ('nearly', 'RB'): 1,
#  ('new', 'JJ'): 1,
#  ('nice', 'JJ'): 1,
#  ('popular', 'JJ'): 1,
#  ('positive', 'JJ'): 1,
#  ('powerful', 'JJ'): 1,
#  ('proud', 'JJ'): 1,
#  ('proudly', 'RB'): 1,
#  ('quickly', 'RB'): 1,
#  ('ready', 'JJ'): 1,
#  ('real', 'JJ'): 1,
#  ('really', 'RB'): 1,
#  ('right', 'JJ'): 1,
#  ('right', 'VBD'): 1,
#  ('secure', 'VB'): 1,
#  ('serious', 'JJ'): 1,
#  ('smart', 'VB'): 1,
#  ('special', 'JJ'): 1,
#  ('strong', 'JJ'): 1,
#  ('strongly', 'RB'): 1,
#  ('successful', 'JJ'): 1,
#  ('top', 'JJ'): 1,
#  ('tremendous', 'JJ'): 1,
#  ('true', 'JJ'): 1,
#  ('unpopular', 'JJ'): 1,
#  ('very', 'RB'): 1,
#  ('wants', 'VBZ'): 1,
#  ('welcome', 'JJ'): 1,
#  ('welcome', 'VB'): 1,
#  ('win', 'VB'): 1,
#  ('winning', 'VBG'): 1,
#  ('wonderful', 'JJ'): 1,
#  ('written', 'VBN'): 1}

# %%
pprint([combWord for combWord in combWords if len(combWord)>0])
# Out:
# [[('easy', 'JJ')],
#  [('little', 'JJ')],
#  [('many', 'JJ')],
#  [('happy', 'JJ')],
#  [('brave', 'VBP')],
#  [('welcome', 'VB')],
#  [('incredible', 'JJ')],
#  [('wonderful', 'JJ')],
#  [('major', 'JJ')],
#  [('incredible', 'JJ')],
#  [('better', 'JJR')],
#  [('illegal', 'JJ')],
#  [('free', 'JJ')],
#  [('higher', 'JJR')],
#  [('wonderful', 'JJ')],
#  [('first', 'JJ')],
#  [('incredible', 'JJ')],
#  [('right', 'JJ')],
#  [('expected', 'VBN')],
#  [('great', 'JJ')],
#  [('more', 'JJR')],
#  [('many', 'JJ')],
#  [('top', 'JJ')],
#  [('bad', 'JJ')],
#  [('wants', 'VBZ')],
#  [('stupid', 'JJ')],
#  [('happy', 'JJ')],
#  [('bad', 'JJ')],
#  [('many', 'JJ')],
#  [('bad', 'JJ')],
#  [('small', 'JJ')],
#  [('great', 'JJ')],
#  [('great', 'JJ')],
#  [('beautiful', 'JJ')],
#  [('legal', 'JJ')],
#  [('be', 'VB'), ('happy', 'JJ')],
#  [('strongly', 'RB')],
#  [('true', 'JJ')],
#  [('great', 'JJ')],
#  [('welcome', 'VB')],
#  [('incredible', 'JJ')],
#  [('interested', 'JJ')],
#  [('great', 'JJ')],
#  [('winning', 'VBG')],
#  [('many', 'JJ')],
#  [('strongly', 'RB')],
#  [('right', 'VBD')],
#  [('true', 'JJ')],
#  [('best', 'JJS')],
#  [('popular', 'JJ')],
#  [('serious', 'JJ')],
#  [('great', 'JJ')],
#  [('insecure', 'JJ')],
#  [('great', 'JJ')],
#  [('powerful', 'JJ')],
#  [('able', 'JJ')],
#  [('very', 'RB'), ('sad', 'JJ')],
#  [('written', 'VBN')],
#  [('incredible', 'JJ')],
#  [('heavy', 'JJ')],
#  [('long', 'JJ')],
#  [('hard', 'RB')],
#  [('bad', 'JJ')],
#  [('terrible', 'JJ')],
#  [('terrible', 'JJ')],
#  [('extraordinary', 'JJ')],
#  [('great', 'JJ')],
#  [('stupidly', 'RB')],
#  [('horrible', 'JJ')],
#  [('hard', 'JJ')],
#  [('many', 'JJ'), ('positive', 'JJ')],
#  [('political', 'JJ'), ('long', 'JJ')],
#  [('come', 'VB'), ('not', 'RB')],
#  [('more', 'JJR')],
#  [('love', 'VBP')],
#  [('secure', 'VB')],
#  [('important', 'JJ'), ('great', 'JJ')],
#  [('successful', 'JJ')],
#  [('happy', 'JJ')],
#  [('outdated', 'VBN')],
#  [('nearly', 'RB')],
#  [('desperately', 'RB')],
#  [('desperate', 'JJ')],
#  [('great', 'JJ')],
#  [('other', 'JJ')],
#  [('top', 'JJ')],
#  [('fast', 'RB')],
#  [('nice', 'JJ')],
#  [('live', 'JJ')],
#  [('new', 'JJ')],
#  [('not', 'RB')],
#  [('wonderful', 'JJ')],
#  [('innocent', 'JJ')],
#  [('strong', 'JJ')],
#  [('difficult', 'JJ')],
#  [('very', 'RB')],
#  [('great', 'JJ')],
#  [('tremendous', 'JJ')],
#  [('important', 'JJ')],
#  [('first', 'RB')],
#  [('filled', 'VBN')],
#  [('unnecessary', 'JJ'), ('other', 'JJ')],
#  [('great', 'JJ')],
#  [('win', 'VB')],
#  [('nice', 'JJ')],
#  [('great', 'JJ')],
#  [('looking', 'VBG'), ('good', 'JJ'), ('great', 'JJ')],
#  [('foreign', 'JJ')],
#  [('proud', 'JJ')],
#  [('important', 'JJ')],
#  [('long', 'JJ')],
#  [('first', 'JJ')],
#  [('much', 'JJ')],
#  [('incredible', 'JJ')],
#  [('including', 'VBG')],
#  [('welcome', 'VB')],
#  [('great', 'JJ')],
#  [('great', 'JJ')],
#  [('desperately', 'RB')],
#  [('unnecessary', 'JJ'), ('other', 'JJ')],
#  [('more', 'JJR')],
#  [('special', 'JJ')],
#  [('simple', 'JJ')],
#  [('desperately', 'RB')],
#  [('good', 'JJ')],
#  [('incredible', 'JJ')],
#  [('really', 'RB')],
#  [('great', 'JJ')],
#  [('sadly', 'RB')],
#  [('interested', 'VBN')],
#  [('secret', 'JJ')],
#  [('long', 'RB')],
#  [('small', 'JJ')],
#  [('greatest', 'JJS')],
#  [('great', 'JJ')],
#  [('greatest', 'JJS')],
#  [('more', 'JJR')],
#  [('cutting', 'VBG')],
#  [('great', 'JJ')],
#  [('incredible', 'JJ')],
#  [('great', 'JJ')],
#  [('amazing', 'JJ')],
#  [('tremendous', 'JJ')],
#  [('corrupt', 'JJ')],
#  [('intense', 'JJ')],
#  [('down', 'RB')],
#  [('happy', 'JJ')],
#  [('boring', 'JJ')],
#  [('good', 'JJ')],
#  [('sloppy', 'JJ')],
#  [('new', 'JJ')],
#  [('many', 'JJ')],
#  [('great', 'JJ')],
#  [('unnecessary', 'JJ')],
#  [('beautiful', 'JJ')],
#  [('failed', 'JJ')],
#  [('beloved', 'JJ')],
#  [('great', 'JJ')],
#  [('many', 'JJ')],
#  [('hard', 'JJ')],
#  [('top', 'JJ')],
#  [('terrible', 'JJ')],
#  [('more', 'JJR')],
#  [('terrible', 'JJ')],
#  [('smart', 'VB')],
#  [('down', 'RB')],
#  [('roughly', 'RB')],
#  [('good', 'JJ')],
#  [('desperately', 'RB')],
#  [('many', 'JJ')],
#  [('little', 'JJ')],
#  [('disappointed', 'VBD')],
#  [('better', 'JJR')],
#  [('unfair', 'JJ')],
#  [('highly', 'RB'), ('unpopular', 'JJ')],
#  [('full', 'JJ')],
#  [('hated', 'JJ')],
#  [('wants', 'VBZ')],
#  [('much', 'RB')],
#  [('true', 'JJ')],
#  [('fantastic', 'JJ')],
#  [('large', 'JJ'), ('meaningful', 'JJ')],
#  [('great', 'JJ')],
#  [('appreciated', 'VBN')],
#  [('far', 'RB')],
#  [('true', 'JJ')],
#  [('more', 'RBR')],
#  [('most', 'JJS')],
#  [('more', 'RBR')],
#  [('more', 'JJR')],
#  [('everyday', 'JJ')],
#  [('tough', 'JJ')],
#  [('nearly', 'RB')],
#  [('more', 'RBR')],
#  [('tremendous', 'JJ')],
#  [('more', 'JJR')],
#  [('approximately', 'RB')],
#  [('many', 'JJ')],
#  [('everyday', 'JJ')],
#  [('good', 'JJ')],
#  [('great', 'JJ')],
#  [('unable', 'JJ')],
#  [('loved', 'VBN')],
#  [('great', 'JJ')],
#  [('great', 'JJ')],
#  [('proudly', 'RB')],
#  [('most', 'RBS')],
#  [('bad', 'JJ')],
#  [('great', 'JJ')],
#  [('incredible', 'JJ')],
#  [('half', 'JJ')],
#  [('brave', 'JJ')],
#  [('live', 'VB')],
#  [('live', 'JJ')],
#  [('great', 'JJ')],
#  [('great', 'JJ')],
#  [('win', 'VB')],
#  [('more', 'RBR')],
#  [('dishonest', 'JJS')],
#  [('worse', 'JJR')],
#  [('top', 'JJ')],
#  [('more', 'JJR')],
#  [('more', 'RBR'), ('fake', 'JJ')],
#  [('dishonest', 'JJS')],
#  [('many', 'JJ')],
#  [('guilty', 'JJ')],
#  [('great', 'JJ')],
#  [('hard', 'RB')],
#  [('weak', 'JJ')],
#  [('weakly', 'JJ')],
#  [('great', 'JJ')],
#  [('first', 'JJ')],
#  [('strong', 'JJ')],
#  [('real', 'JJ')],
#  [('major', 'JJ')],
#  [('wonderful', 'JJ')],
#  [('new', 'JJ')],
#  [('illegal', 'JJ')],
#  [('ready', 'JJ')],
#  [('important', 'JJ')],
#  [('wonderful', 'JJ')],
#  [('great', 'JJ')],
#  [('great', 'JJ')],
#  [('terrible', 'JJ')],
#  [('most', 'RBS')],
#  [('first', 'JJ')],
#  [('complete', 'JJ')],
#  [('previous', 'JJ')],
#  [('tragic', 'JJ')],
#  [('horrible', 'JJ')],
#  [('quickly', 'RB')],
#  [('great', 'JJ')],
#  [('live', 'JJ')],
#  [('new', 'JJ')],
#  [('economic', 'JJ')],
#  [('down', 'RB')],
#  [('hard', 'RB')],
#  [('big', 'JJ')],
#  [('repellent', 'JJ')],
#  [('worst', 'JJS')],
#  [('destroy', 'VB')],
#  [('bad', 'JJ')],
#  [('welcome', 'JJ')],
#  [('delicious', 'JJ')],
#  [("'s", 'VBZ')],
#  [('large', 'JJ')],
#  [('fly', 'VB')],
#  [('happy', 'JJ')],
#  [('delicious', 'JJ')],
#  [("'s", 'VBZ')],
#  [('large', 'JJ')],
#  [('fly', 'VB')],
#  [('happy', 'JJ')]]

# %%
drawGraph(matrix,indexMap)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %%
def getPolarity(sc):
    blob = TextBlob(sc)
    initPol = 0.0
    dueTo=[]
    for t in blob.tags:
        tag = (t[0].lower(),t[1]) 
        if(tag[1] not in toConsider):
            continue
        if(initPol==0.0):
            if(tag in negToPos and negToPos[tag]==1):
                initPol = 1
                dueTo.append(tag)
            elif((tag in posToNeg) and posToNeg[tag]==1):
                initPol = -1
                dueTo.append(tag)
        elif((tag in posToNeg) and posToNeg[tag]==1):
            initPol = -1 * initPol
            dueTo.append(tag)
        elif(tag in negToPos and negToPos[tag]==1):
            initPol  = 1 * initPol
            dueTo.append(tag)
    return (initPol,dueTo)

# %%
sentences = ["I ate a delicious hamburger.",
            "Zack joins the Sprockets Academy Explorers Club at school",
            "Zack gets paired up with Seth, the class bully, and that's dreadful but Zack is excited when he finds a huge galaxy gemmite",
            "A gemmite that large was found in last 100 years",
            "My favorite part is that the bird tried and learned that she could fly",
            "The bird has to decide if it will try to fly",
            "One fateful day they make the acquaintance of the Cotton family",
            "I wish i could fly."]

print("Index Predicted Target")
i=1
accuracy = 0
for sc in sentences:
    predicted,dueTo = getPolarity(sc)
    dummy = sc
    blob = TextBlob(dummy)
    for sentence in blob.sentences:
        target = sentence.sentiment.polarity
    print(str(i)+"       "+str(round(predicted*1.0,1))+"     "+str(round(target,2))+"         "+str(dueTo))
    if(predicted>0 and target>0 or predicted <0 and target<0 or predicted==0.0 and target==0):
        accuracy+=1
    i+=1
print("Accuracy : "+str(accuracy/len(sentences)))
# Out:
# Index Predicted Target
# 1       1.0     1.0         [('delicious', 'JJ')]
# 2       0.0     0.0         []
# 3       -1.0     -0.07         [("'s", 'VBZ')]
# 4       1.0     0.11         [('large', 'JJ')]
# 5       1.0     0.65         [('fly', 'VB')]
# 6       1.0     0.8         [('fly', 'VB')]
# 7       0.0     0.0         []
# 8       1.0     0.8         [('fly', 'VB')]
# Accuracy : 1.0
